# %% [markdown]
# # Key Performance Indicators — Google Play Store Dataset
#
# Figures below are taken directly from the notebook's own printed outputs and observations.
# Where the notebook reported two versions of a metric (deduped vs. not deduped), both are
# shown — see the README note on inconsistent deduplication.
#
# ## Catalog Overview
# | KPI | Value |
# |---|---|
# | Total app records | 10,841 |
# | Unique app categories | 33 |
# | Unique genres | 120 |
# | Unique content rating tiers | 6 |
# | Unique Android version requirements | 34 |
# | Unique app versions ("Current Ver") | 2,833 |
#
# ## Pricing & Monetization
# | KPI | Value |
# |---|---|
# | Free apps (record-level) | 92.6% |
# | Paid apps (record-level) | 7.4% |
# | Free apps (deduped, unique apps) | 92.17% |
# | Paid apps (deduped, unique apps) | 7.83% |
# | Average app price (all apps) | $1.03 |
# | Max app price | $400 |
# | Apps priced above $50 | 24 |
# | Best-performing paid price band | $1–$5 (73 "successful" paid apps — above-average installs & rating) |
# | Avg rating — paid apps | 4.27 |
# | Avg rating — free apps | 4.19 |
# | Total installs — free apps | ~75.07B |
# | Total installs — paid apps | ~57.36M |
#
# ## Ratings
# | KPI | Value |
# |---|---|
# | Average rating | 4.21 / 5.0 |
# | Rating std deviation | 0.48 (low variability) |
# | Modal rating | 4.3 |
# | Rating skew | Left-skewed (most apps rate high) |
# | Highest-rated category (avg) | Events — 4.395 |
# | Lowest-rated category (avg) | Dating — 4.026 |
#
# ## Reviews & Installs
# | KPI | Value |
# |---|---|
# | Average reviews per app | 444,112 |
# | Max reviews (single app) | 78,158,310 |
# | Average installs per app | 15,462,920 |
# | Max installs (single app) | 1,000,000,000 |
# | Modal install count | 1,000,000 |
# | Apps with 400M+ installs | 130 |
# | Reviews–Installs correlation | Strong positive |
# | Rating–Installs correlation | Weak |
# | Reviews–Rating correlation | Weak |
#
# ## App Size
# | KPI | Value |
# |---|---|
# | Average app size | 20.18 MB |
# | Size std deviation | 20.98 MB |
# | Modal size | 13.0 MB |
# | Size skew | Right-skewed (most apps small, few large) |
# | Size–Installs correlation | ~0.048 (negligible) |
# | Size–Rating correlation | Negligible |
#
# ## Content Rating
# | KPI | Value |
# |---|---|
# | "Everyone" | 80.39% |
# | "Teen" | 11.14% |
# | "Mature 17+" | 4.60% |
# | "Everyone 10+" | 3.82% |
# | "Adults only 18+" | 3 apps |
# | Unrated | 2 apps |
#
# ## Category Performance
# | KPI | Value |
# |---|---|
# | Most apps in a category | Family |
# | Fewest apps in a category | Beauty |
# | Top installs by category | Game (3.51B), Communication (3.26B), Productivity (1.42B), Social (1.41B), Tools (1.15B) |
# | Bottom installs by category | Events, Beauty, Parenting, Auto & Vehicles, Medical |
# | Best demand-to-competition ratio | Communication (~35M installs/app across only 315 apps) |
# | High installs + high rating | Game, Productivity, Social |
# | High installs + below-average rating (improvement opportunity) | Communication, Tools, Family, News & Magazines, Photography, Travel & Local, Video Players (Tools & Video Players lowest, avg 4.08) |
# | Most successful paid-app category | Education (avg installs ~150,500, avg rating ~4.75) |
#
# ## Update Recency
# | KPI | Value |
# |---|---|
# | Earliest last-updated date | 2010-05-21 |
# | Latest last-updated date | 2019-01-01 |
# | 75th percentile update date | On/after 2018-07-20 |
# | Days-since-update vs. Installs correlation | -0.10 (weak) |
# | Days-since-update vs. Rating correlation | -0.13 (weak) |
#
# ## User Sentiment (Review Dataset)
# | KPI | Value |
# |---|---|
# | Positive reviews | 19,115 |
# | Negative reviews | 6,341 |
# | Neutral reviews | 4,361 |
# | Review Unavailable | 9,820 |
# | Positive share (of labeled reviews) | Dominant — positive sentiment is most common |
#
# > **Caveat**: several of the KPIs above (category-level install/review sums) were computed
# > on non-deduplicated data in the notebook and may be inflated relative to a true per-app
# > count. Treat category comparisons as directionally correct, not exact, until dedup is
# > standardized.
