# %% [markdown]
# Understanding Data

# %%
#files 
"""
There are two files google play store data and then user review data separtely 
1:Playstore file is for app names and description  and categories of the apps
2:User review file is for reviews and review categorization 
"""
# Out:
# '\nThere are two files google play store data and then user review data separtely \n1:Playstore file is for app names and description  and categories of the apps\n2:User review file is for reviews and review categorization \n'

# %%
#importing liabraries
import numpy as np
import pandas as pd 
import csv

# %%
#reading files 
playstoredata=pd.read_csv("../DATA/RawData/googleplaystore.csv")
processedplaysotedata=pd.read_csv("../DATA/RawData/ProcessedData/processedplaystoredata.csv")

# %% [markdown]
# Understanding playstore data whole file

# %% [markdown]
# df.shape
# df.size
# df.info()
# df.describe()
# df.describe(include="object")
# df.head()
# df.tail()
# df.sample(5)
# df.duplicated().sum()
# df.isna().sum()

# %%
#shape of playstoredata
psshape=playstoredata.shape
print(psshape)
# Out:
# (10841, 13)

# %%
#size
pssize=playstoredata.size
print(pssize)
# Out:
# 140933

# %%
#head
pssample=playstoredata.head(10)
print(pssample)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
#tail
pstail=playstoredata.tail(10)
print(pstail)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %%
#dublicates
psdublicates=playstoredata[playstoredata.duplicated()]
print(psdublicates)
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#missingvalues count 
psmissingvalues=playstoredata.isna().sum()
print(psmissingvalues)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# Understanding columns of playstore data

# %%
columns=playstoredata.columns
print(columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#accessing coloumns
app=playstoredata["App"]
category=playstoredata["Category"]
rating=playstoredata["Rating"]
reviews=playstoredata["Reviews"]
size=playstoredata["Size"]
installs=playstoredata["Installs"]
type=playstoredata["Type"]
price=playstoredata["Price"]
contentrating=playstoredata["Content Rating"]
genres=playstoredata["Genres"]
lastupdated=playstoredata["Last Updated"]
currentversion=playstoredata["Current Ver"]
andriodversion=playstoredata["Android Ver"]

# %% [markdown]
# column wise analyis

# %% [markdown]
# app

# %%
appuniques=app.unique()
print(appuniques)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']

# %% [markdown]
# analyzing processedplaydotedata

# %% [markdown]
# raw info

# %%
#information 
psinfo=playstoredata.info()
print(psinfo)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# processed info

# %%
proccedplaystoredatainfo=processedplaysotedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       10841 non-null  int64
#  1   App              10841 non-null  object
#  2   Category         10841 non-null  object
#  3   Rating           10841 non-null  float64
#  4   Reviews          10841 non-null  float64
#  5   Size             10841 non-null  float64
#  6   Installs         10841 non-null  float64
#  7   Type             10841 non-null  object
#  8   Price            10841 non-null  float64
#  9   Content Rating   10841 non-null  object
#  10  Genres           10841 non-null  object
#  11  Last Updated     10841 non-null  object
#  12  Current Version  10841 non-null  object
#  13  Android Ver      10841 non-null  object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# UNDERSTANDING USER REVIEW DATA

# %%
userreviewdata=pd.read_csv("../DATA/RawData/googleplaystore_user_reviews.csv")
processeduserreviewdata=pd.read_csv("../DATA/RawData/ProcessedData/processeduserreview.csv")

# %%
#shape ,size, data types 
print("shape",userreviewdata.shape)
print("size",userreviewdata.size)
print("datatype",userreviewdata.dtypes)
# Out:
# shape (64295, 5)
# size 321475
# datatype App                        object
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %%
#information 
print("information",userreviewdata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB
# information None

# %%
#infoprocessed ur
print(processeduserreviewdata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30679 entries, 0 to 30678
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     30679 non-null  object
#  1   Translated_Review       30679 non-null  object
#  2   Sentiment               30679 non-null  object
#  3   Sentiment_Polarity      30679 non-null  float64
#  4   Sentiment_Subjectivity  30679 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.2+ MB
# None

# %%
#desciption
print("describing",userreviewdata.describe())
# Out:
# describing        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000
